# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojin1699/fooddetector-mlmodel/blob/master/fooddetector-train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir /content/drive/MyDrive/중간발표/dataset

# %%
# !pip install roboflow

# %%
# download train data
# %cd /content/drive/MyDrive/중간발표/dataset

from roboflow import Roboflow
rf = Roboflow(api_key="H4CjeAKmhqurHN5n4zjh")
project = rf.workspace().project("fooddetector")
dataset = project.version(1).download("yolov5")
# Out:
# /content/drive/MyDrive/중간발표/dataset
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to FoodDetector-1 in yolov5pytorch:: 100%|██████████| 17844/17844 [02:01<00:00, 146.35it/s]

# %%
# download validation data
# %cd /content/drive/MyDrive/중간발표/dataset

from roboflow import Roboflow
rf = Roboflow(api_key="ziTSqLVyi1Ctcjc0T695")
project = rf.workspace().project("fooddetector-val")
dataset = project.version(1).download("yolov5")

# %%
# data.yaml train, valid 폴더 경로 수정

# %%
# %cd /content/drive/MyDrive/중간발표

# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# /content/drive/MyDrive/중간발표
# Cloning into 'yolov5'...
# remote: Enumerating objects: 9955, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 9955 (delta 14), reused 7 (delta 3), pack-reused 9923
# Receiving objects: 100% (9955/9955), 10.27 MiB | 9.78 MiB/s, done.
# Resolving deltas: 100% (6890/6890), done.

# %%
# %cd /content/drive/MyDrive/중간발표/yolov5
# !pip install -r requirements.txt

# %%
# %cd /
from glob import glob

train_img_list = glob('/content/drive/MyDrive/중간발표/dataset/train/images/*.jpg')
val_img_list = glob('/content/drive/MyDrive/중간발표/dataset/valid/images/*.jpg')

print(len(train_img_list), len(val_img_list))

# %%
with open('/content/drive/MyDrive/중간발표/yolov5/train.txt', 'w') as f:
  f.write('\n'.join(train_img_list) + '\n')

with open('/content/drive/MyDrive/중간발표/yolov5/val.txt', 'w') as f:
  f.write('\n'.join(val_img_list) + '\n')

# %%
# %cd /content/drive/MyDrive/중간발표/yolov5

# !python train.py  --img 416 --batch 16 --data /content/drive/MyDrive/중간발표/dataset/data.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name fooddetector_yolov5s_results_v2
# Out:
# /content/drive/MyDrive/중간발표/yolov5
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=/content/drive/MyDrive/중간발표/dataset/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=300, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=fooddetector_yolov5s_results_v2, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-66-g3364379 torch 1.9.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir /content/drive/MyDrive/중간발표/yolov5/runs

# %%
from IPython.display import Image
import os

#val_img_path = val_img_list[2]
val_img_path = '/content/drive/MyDrive/workspace/example2.jpg'

# !python /content/drive/MyDrive/중간발표/yolov5/detect.py --weights /content/drive/MyDrive/중간발표/yolov5/runs/train/fooddetector_yolov5s_results_v2/weights/best.pt --img 416 --conf 0.2 --source "{val_img_path}"
# Out:
# detect: weights=['/content/drive/MyDrive/중간발표/yolov5/runs/train/fooddetector_yolov5s_results_v2/weights/best.pt'], source=/content/drive/MyDrive/workspace/example2.jpg, imgsz=[416, 416], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-66-g3364379 torch 1.9.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7026307 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/workspace/example2.jpg: 320x416 1 ssalbap, 1 geundaedoenjangguk, 1 eomukbokkeum, 1 mechurialjangjorim, 1 sigeumchinamul, Done. (0.010s)
# Speed: 0.4ms pre-process, 9.7ms inference, 1.2ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp10

# %%
Image(os.path.join('/content/drive/MyDrive/중간발표/yolov5/runs/detect/exp9', os.path.basename(val_img_path)))
